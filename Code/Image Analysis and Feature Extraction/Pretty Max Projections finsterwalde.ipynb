# %%
import tribolium_clustering as tc
import pyclesperanto_prototype as cle
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Finsterwalde

# %%
finster = tc.processed_dataset(tc.get_folder_path())

# %%
t0 = finster.get_intensity_image(0)

max_proj_t0 = np.max(t0,axis=0)

plt.figure(figsize = (10,20))

plt.imshow(max_proj_t0,cmap = 'gray')
plt.axis('off')
# Out:
# (-0.5, 511.5, 963.5, -0.5)

# %%
def nice_max_projection(lund_dataset,index,
                        y_cutoff_bottom=1024,y_cutoff_top=0,
                        x_cutoff_right=512,x_cutoff_left=0):
    import numpy as np
    import matplotlib.pyplot as plt
    t_index = lund_dataset.get_intensity_image(index)

    max_proj = np.max(t_index,axis=0)[y_cutoff_top:y_cutoff_bottom,x_cutoff_left:x_cutoff_right]

    plt.figure(figsize = (10,20))

    plt.imshow(max_proj,cmap = 'gray')
    plt.axis('off')
    
nice_max_projection(finster,3)

# %%
def save_max_proj_in_folder(lund_dataset,index, folder,
                        y_cutoff_bottom=1024,y_cutoff_top=0,
                        x_cutoff_right=512,x_cutoff_left=0):
    import numpy as np
    import matplotlib as plt
    from skimage import io
    
    t_index = lund_dataset.get_intensity_image(index)

    max_proj = np.max(t_index,axis=0)[y_cutoff_top:y_cutoff_bottom,x_cutoff_left:x_cutoff_right]
    
    io.imsave(folder+'max_projection_idx_{}.png'.format(index),max_proj)
    
save_folder = tc.get_folder_path()

save_max_proj_in_folder(finster,0,save_folder)
# Out:
# Lossy conversion from float32 to uint8. Range [123.0, 948.0]. Convert image to uint8 prior to saving to suppress this warning.

# %%
for i in range(32):
    save_max_proj_in_folder(finster,i,save_folder)
# Out:
# Lossy conversion from float32 to uint8. Range [123.0, 948.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [123.0, 938.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [123.0, 931.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [123.0, 1020.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [124.0, 1052.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [123.0, 1081.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [123.0, 1164.0]. Convert image to uint8 prior to saving to suppress this warning.
# ...

# %%
def save_z_slice_in_folder(lund_dataset,index, folder,zs_index,
                        y_cutoff_bottom=1024,y_cutoff_top=0,
                        x_cutoff_right=512,x_cutoff_left=0):
    import numpy as np
    import matplotlib as plt
    from skimage import io
    
    t_index = lund_dataset.get_intensity_image(index)

    z_slice = t_index[zs_index]
    cropped = z_slice[y_cutoff_top:y_cutoff_bottom,x_cutoff_left:x_cutoff_right]
    
    io.imsave(folder+'z_slice{i}_idx_{j}.png'.format(i=zs_index, j=index),cropped)
    
for i in range(25):
    save_z_slice_in_folder(lund,i,save_folder,zs_index = 40)
# Out:
# Lossy conversion from float32 to uint8. Range [120.0, 942.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [120.0, 939.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [118.0, 912.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [116.0, 953.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [118.0, 956.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [114.0, 995.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [119.0, 969.0]. Convert image to uint8 prior to saving to suppress this warning.
# ...

# %%
t0 = finster.get_intensity_image(6).T[200]

z_slice = t0[:, ::-1]
plt.figure(figsize = (10,20))

plt.imshow(z_slice,cmap = 'gray')
plt.axis('off')
# Out:
# (-0.5, 296.5, 963.5, -0.5)

# %%
def save_z_slice_in_folder(lund_dataset,index, folder,zs_index,
                        y_cutoff_bottom=950,y_cutoff_top=0,
                        x_cutoff_right=512,x_cutoff_left=0):
    import numpy as np
    import matplotlib as plt
    from skimage import io
    
    t0 = lund_dataset.get_intensity_image(index).T[zs_index]


    z_slice = t0
    cropped = z_slice[:, ::-1]
    
    io.imsave(folder+'z_slice{i}_idx_{j}.png'.format(i=zs_index, j=index),cropped)
    
for i in range(32):
    save_z_slice_in_folder(finster,i,save_folder,zs_index = 300)
# Out:
# Lossy conversion from float32 to uint8. Range [112.0, 688.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [112.0, 708.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [113.0, 629.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [109.0, 647.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [109.0, 604.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [113.0, 616.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [111.0, 702.0]. Convert image to uint8 prior to saving to suppress this warning.
# ...
