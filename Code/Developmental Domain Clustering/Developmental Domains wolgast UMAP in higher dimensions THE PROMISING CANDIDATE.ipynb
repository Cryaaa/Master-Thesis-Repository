# %%
import tribolium_clustering as tc
import pyclesperanto_prototype as cle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA, SparsePCA
from sklearn.cluster import KMeans
from sklearn.metrics import calinski_harabasz_score, silhouette_score

lund_folder = tc.get_folder_path('Wolgast Folder')
lund = tc.processed_dataset(lund_folder)

lund_combined_thesis_props = lund.get_combined_thesis_props_no_correlation()
lund_combined_thesis_props.keys()
# Out:
# No Predictions in Regionprops of D:/Uni/MSTER TUD/Master Thesis/output data/Wolgast Gastrulation Labels//
# Index(['area', 'bbox_area', 'extent', 'feret_diameter_max', 'max_intensity',
#        'mean_intensity', 'min_intensity', 'solidity', 'centroid-0',
#        'centroid-1', 'centroid-2', 'image_stdev',
#        'avg distance of 6 closest points',
#        'stddev distance of 6 closest points', 'touching neighbor count',
#        'aspect_ratio'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_thesis_props_lund = scaler.fit_transform(lund_combined_thesis_props)

import umap

umap_reducer = umap.UMAP(n_components=7,n_neighbors=400,random_state=42)
embedding_7dims = umap_reducer.fit_transform(scaled_thesis_props_lund)

# %%
predictions_k2_to_8 = []

for i in range(2,9):
    clusterer = KMeans(n_clusters= i ,max_iter=10000, init= 'k-means++', random_state= 42)
    prediction = clusterer.fit_predict(embedding_7dims)
    predictions_k2_to_8.append(prediction)
    
ch_scores = [calinski_harabasz_score(embedding_7dims,pred) for pred in predictions_k2_to_8]
ASW_scores = [silhouette_score(embedding_7dims,pred) for pred in predictions_k2_to_8]

# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 400
from matplotlib import cm
x = np.array(range(6))
cmap_list = cm.get_cmap(plt.get_cmap('tab20'))(x)[np.newaxis, :, :3][0]

lw = 2
big_fs = 15
small_fs = 14
a = 1

fig, ax1 = plt.subplots(1,1,figsize = (5,3))

ax1.plot(range(2,9),ch_scores,
         linewidth=lw,alpha =a,
         color = cmap_list[0])


ax1.set_xlabel('Number of Clusters', fontsize =big_fs)
ax1.set_ylabel('CH Score',fontsize= big_fs,color = cmap_list[0])
plt.xticks(fontsize=small_fs)


# twin object for two different y-axis on the sample plot
ax2=ax1.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(range(2,9), ASW_scores,
         linewidth=lw,alpha =a,
         color = cmap_list[2])
ax2.set_ylabel('Silhouette Score',fontsize= big_fs,color = cmap_list[2])
plt.show()

# %%
def gen_cluster_image_and_orig_image_from_dataset(dataset,timepoint,prediction, all_timepoint_predictionlist = True):
    from tribolium_clustering.data_visualisation import generate_parametric_cluster_image
    from pyclesperanto_prototype import push
    
    labels      = dataset.get_labels(timepoint)
    orig_image  = dataset.get_intensity_image(timepoint)
    cum_indices = dataset.cumulative_label_lengths()
    
    
    if all_timepoint_predictionlist:
        timepoint_pred = prediction[cum_indices[timepoint]:cum_indices[timepoint+1]]
    else:
        timepoint_pred = prediction
    
    cluster_image = generate_parametric_cluster_image(labels, push(labels), timepoint_pred)
    
    return cluster_image, orig_image

np_cmap = tc.napari_label_cmap()
rot_lund = (0,180,0)
import napari

img_5cl_t0, original_img_t0 = gen_cluster_image_and_orig_image_from_dataset(lund,0,predictions_k2_to_8[3])

viewer = napari.Viewer(ndisplay=3)
viewer.add_image(original_img_t0, rotate=rot_lund)
viewer.add_labels(img_5cl_t0,rotate=rot_lund,color = np_cmap)

napari.utils.nbscreenshot(viewer,canvas_only=True)
# Out:
# No Predictions in Regionprops of D:/Uni/MSTER TUD/Master Thesis/output data/Wolgast Gastrulation Labels//
# C:\Users\ryans\anaconda3\envs\mstr_v4\lib\site-packages\napari\_qt\__init__.py:54: UserWarning:
#
# napari was tested with QT library `>=5.12.3`.
# The version installed is 5.9.7. Please report any issues with
# this specific QT version at https://github.com/Napari/napari/issues.
#   warn(message=warn_message)
# WARNING: DirectWrite: CreateFontFaceFromHDC() failed (Gibt einen Fehler in einer Eingabedatei an, zum Beispiel eine Schriftartdatei.) for QFontDef(Family="", pointsize=12, pixelsize=16, styleHint=5, weight=50, stretch=100, hintingPreference=0) LOGFONT("MS Sans Serif", lfWidth=0, lfHeight=-16) dpi=96

# %%
img_5cl, original_img = gen_cluster_image_and_orig_image_from_dataset(lund,6,predictions_k2_to_8[3])

viewer = napari.Viewer(ndisplay=3)
viewer.add_image(original_img, rotate=rot_lund)
viewer.add_labels(img_5cl,rotate=rot_lund,color = np_cmap)

napari.utils.nbscreenshot(viewer,canvas_only=True)
# Out:
# No Predictions in Regionprops of C:/Users/ryans/Documents/output data (big)/Wolgast Gastrulation Labels//

# %%
img_5cl, original_img = gen_cluster_image_and_orig_image_from_dataset(lund,12,predictions_k2_to_8[3])

viewer = napari.Viewer(ndisplay=3)
viewer.add_image(original_img, rotate=rot_lund)
viewer.add_labels(img_5cl,rotate=rot_lund,color = np_cmap)

napari.utils.nbscreenshot(viewer,canvas_only=True)
# Out:
# No Predictions in Regionprops of C:/Users/ryans/Documents/output data (big)/Wolgast Gastrulation Labels//

# %%
img_5cl, original_img = gen_cluster_image_and_orig_image_from_dataset(lund,24,predictions_k2_to_8[3])

viewer = napari.Viewer(ndisplay=3)
viewer.add_image(original_img, rotate=rot_lund)
viewer.add_labels(img_5cl,rotate=rot_lund,color = np_cmap)

napari.utils.nbscreenshot(viewer,canvas_only=True)
# Out:
# No Predictions in Regionprops of C:/Users/ryans/Documents/output data (big)/Wolgast Gastrulation Labels//
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-9-13e3a951b50f> in <module>
#       3 viewer = napari.Viewer(ndisplay=3)
#       4 viewer.add_image(original_img, rotate=rot_lund)
# ----> 5 viewer.add_labels(img_5cl,rotate=rot_lund,color = np_cmap)
#       6
#       7 napari.utils.nbscreenshot(viewer,canvas_only=True)
#
# <string> in add_labels(self, data, num_colors, properties, color, seed, name, metadata, scale, translate, rotate, shear, affine, opacity, blending, visible, multiscale)
#
# ~\Anaconda3\envs\mstr_v1\lib\_collections_abc.py in append(self, value)
#     960     def append(self, value):
#     961         'S.append(value) -- append value to the end of the sequence'
# --> 962         self.insert(len(self), value)
#     963
#     964     def clear(self):
#
# ~\Anaconda3\envs\mstr_v1\lib\site-packages\napari\components\layerlist.py in insert(self, index, value)
#      83         new_layer = self._type_check(value)
#      84         new_layer.name = self._coerce_name(new_layer.name)
# ---> 85         super().insert(index, new_layer)
#      86
#      87         # required for deprecated layer.selected property.  remove after 0.4.9
#
# ~\Anaconda3\envs\mstr_v1\lib\site-packages\napari\utils\events\containers\_selectable_list.py in insert(self, index, value)
#      61
#      62     def insert(self, index: int, value: _T):
# ---> 63         super().insert(index, value)
#      64         if self._activate_on_insert:
#      65             # Make layer selected and unselect all others
#
# ~\Anaconda3\envs\mstr_v1\lib\site-packages\napari\utils\events\containers\_evented_list.py in insert(self, index, value)
#     177         self.events.inserting(index=index)
#     178         super().insert(index, value)
# --> 179         self.events.inserted(index=index, value=value)
#     180         self._connect_child_emitters(value)
#     181
#
# ~\Anaconda3\envs\mstr_v1\lib\site-packages\napari\utils\events\event.py in __call__(self, *args, **kwargs)
#     571                     continue
#     572
# --> 573                 self._invoke_callback(cb, event)
#     574                 if event.blocked:
#     575                     break
#
# ~\Anaconda3\envs\mstr_v1\lib\site-packages\napari\utils\events\event.py in _invoke_callback(self, cb, event)
#     593             cb(event)
#     594         except Exception:
# --> 595             _handle_exception(
#     596                 self.ignore_callback_errors,
#     597                 self.print_callback_errors,
#
# ~\Anaconda3\envs\mstr_v1\lib\site-packages\napari\utils\events\event.py in _invoke_callback(self, cb, event)
#     591     def _invoke_callback(self, cb: Callback, event: Event):
#     592         try:
# --> 593             cb(event)
#     594         except Exception:
#     595             _handle_exception(
#
# ~\Anaconda3\envs\mstr_v1\lib\site-packages\napari\components\viewer_model.py in _on_add_layer(self, event)
#     447         self._on_grid_change(None)
#     448         # Slice current layer based on dims
# --> 449         self._update_layers(layers=[layer])
#     450
#     451         if len(self.layers) == 1:
#
# ~\Anaconda3\envs\mstr_v1\lib\site-packages\napari\components\viewer_model.py in _update_layers(self, event, layers)
#     288         layers = layers or self.layers
#     289         for layer in layers:
# --> 290             layer._slice_dims(
#     291                 self.dims.point, self.dims.ndisplay, self.dims.order
#     292             )
#
# ~\Anaconda3\envs\mstr_v1\lib\site-packages\napari\layers\base\base.py in _slice_dims(self, point, ndisplay, order)
#     873         # Update the point values
#     874         self._dims_point = point[offset:]
# --> 875         self._update_dims()
#     876         self._set_editable()
#     877
#
# ~\Anaconda3\envs\mstr_v1\lib\site-packages\napari\layers\base\base.py in _update_dims(self, event)
#     542         self._ndim = ndim
#     543
# --> 544         self.refresh()
#     545
#     546     @property
#
# ~\Anaconda3\envs\mstr_v1\lib\site-packages\napari\layers\base\base.py in refresh(self, event)
#     944         """Refresh all layer data based on current view slice."""
#     945         if self.visible:
# --> 946             self.set_view_slice()
#     947             self.events.set_data()
#     948             self._update_thumbnail()
#
# ~\Anaconda3\envs\mstr_v1\lib\site-packages\napari\layers\base\base.py in set_view_slice(self)
#     808     def set_view_slice(self):
#     809         with self.dask_optimized_slicing():
# --> 810             self._set_view_slice()
#     811
#     812     @abstractmethod
#
# ~\Anaconda3\envs\mstr_v1\lib\site-packages\napari\layers\image\image.py in _set_view_slice(self)
#     609             self, image_indices, image, thumbnail_source
#     610         )
# --> 611         self._load_slice(data)
#     612
#     613     @property
#
# ~\Anaconda3\envs\mstr_v1\lib\site-packages\napari\layers\image\image.py in _load_slice(self, data)
#     629         if self._slice.load(data):
#     630             # The load was synchronous.
# --> 631             self._on_data_loaded(data, sync=True)
#     632         else:
#     633             # The load will be asynchronous. Signal that our self.loaded
#
# ~\Anaconda3\envs\mstr_v1\lib\site-packages\napari\layers\image\image.py in _on_data_loaded(self, data, sync)
#     653
#     654         # Pass the loaded data to the slice.
# --> 655         if not self._slice.on_loaded(data):
#     656             # Slice rejected it, was it for the wrong indices?
#     657             return
#
# ~\Anaconda3\envs\mstr_v1\lib\site-packages\napari\layers\image\_image_slice.py in on_loaded(self, data)
#     140
#     141         # Display the newly loaded data.
# --> 142         self._set_raw_images(data.image, data.thumbnail_source)
#     143         self.loaded = True
#     144         return True  # data was used.
#
# ~\Anaconda3\envs\mstr_v1\lib\site-packages\napari\layers\image\_image_slice.py in _set_raw_images(self, image, thumbnail_source)
#      98             image = np.clip(image, 0, 1)
#      99             thumbnail_source = np.clip(thumbnail_source, 0, 1)
# --> 100         self.image.raw = image
#     101
#     102         # save a computation of view image if thumbnail and image is equal
#
# ~\Anaconda3\envs\mstr_v1\lib\site-packages\napari\layers\image\_image_view.py in raw(self, raw_image)
#      76
#      77         # Update the view image based on this new raw image.
# ---> 78         self._view = self.image_converter(raw_image)
#
# ~\Anaconda3\envs\mstr_v1\lib\site-packages\napari\layers\labels\labels.py in _raw_to_displayed(self, raw)
#     870             and self._color_mode == LabelColorMode.DIRECT
#     871         ):
# --> 872             u, inv = np.unique(raw, return_inverse=True)
#     873             image = np.array(
#     874                 [
#
# <__array_function__ internals> in unique(*args, **kwargs)
#
# ~\Anaconda3\envs\mstr_v1\lib\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     260     ar = np.asanyarray(ar)
#     261     if axis is None:
# --> 262         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     263         return _unpack_tuple(ret)
#     264
#
# ~\Anaconda3\envs\mstr_v1\lib\site-packages\numpy\lib\arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     327     mask[1:] = aux[1:] != aux[:-1]
#     328
# --> 329     ret = (aux[mask],)
#     330     if return_index:
#     331         ret += (perm[mask],)
#
# MemoryError: Unable to allocate 614. MiB for an array with shape (160956416,) and data type uint32

# %%
save_folder = tc.get_folder_path('hope')
np.save(save_folder+'embedding 7dims 400 neighbours wolgast.npy', embedding_7dims)
np.save(save_folder+'predictions for cluster numbers 2 - 8.npy', predictions_k2_to_8)
